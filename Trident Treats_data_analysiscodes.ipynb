# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("TridentTreatsSupermarket2025_totally_real_not_fabricated.csv")

# %%
data = pd.read_csv("TridentTreatsSupermarket2025_totally_real_not_fabricated.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of                   Name                         Email Address Nickname  \
# 0          José Clarke        kendrabest760@tridenttreats.bb    ken41
# 1        Zoë Callender         aliciajordan285@bdsconnect.bb    ali37
# 2           Renée Best           omarholder876@bdsconnect.bb    oma22
# 3      François Holder          devinjordan864@caribmail.com    dev39
# 4         Mårlon Forde        mårlongittens371@bdsconnect.bb    mår27
# ..                 ...                                   ...      ...
# 295       Devin Holder          devinholder102@caribmail.com      NaN
# 296  Alicia Brathwaite  aliciabrathwaite780@tridenttreats.bb      NaN
# 297       Tanya Holder         tanyaholder917@islandshop.net    tan96
# 298       Kendra Hinds         kendrahinds859@islandshop.net    ken73
# 299      Kendra Clarke         kendraclarke851@caribmail.com    ken73
#
#                                      Home Address    Password      Salt  \
# ...

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.continuum',
#  '.dbus-keyrings',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '.vscode',
#  'anaconda3',
#  'anaconda3-1',
#  'anaconda_projects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{2bece5e1-0114-11f0-969c-a43b759872f7}.TM.blf',
#  'NTUSER.DAT{2bece5e1-0114-11f0-969c-a43b759872f7}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{2bece5e1-0114-11f0-969c-a43b759872f7}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'pspp.jnl',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Trident Treats_data_analysis.ipynb',
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("TridentTreatsSupermarket2025_totally_real_not_fabricated.csv")

# %%
df.head()
# Out:
#               Name                   Email Address Nickname  \
# 0      José Clarke  kendrabest760@tridenttreats.bb    ken41
# 1    Zoë Callender   aliciajordan285@bdsconnect.bb    ali37
# 2       Renée Best     omarholder876@bdsconnect.bb    oma22
# 3  François Holder    devinjordan864@caribmail.com    dev39
# 4     Mårlon Forde  mårlongittens371@bdsconnect.bb    mår27
#
#                                    Home Address    Password      Salt  \
# 0  36 Grazettes Main Road, St. Philip, Barbados  n](l.2edlB  oGMbJmTP
# 1            27 Bank Hall, St. Philip, Barbados  lWmTS:Hf~6  Ih7yfJs1
# 2         72 Country Road, St. Philip, Barbados  6>UuVTA\I`  7RPeMOkI
# 3     207 Atlantic Shores, St. Philip, Barbados  OZIiB+|OB@  Fz46PDjq
# 4       127 Two Mile Hill, St. Philip, Barbados  lgot=u^2/i  yyMDHqJ3
#
#     Birthdate  Phone Number  Store ID  Gender Account Type        Branch
# 0  1999-09-14  246-425-8359    1603.0  Female     Standard       Oistins
# ...

# %%
df.shape
# Out:
# (300, 12)

# %%
df.columns
# Out:
# Index(['Name', 'Email Address', 'Nickname', 'Home Address', 'Password', 'Salt',
#        'Birthdate', 'Phone Number', 'Store ID', 'Gender', 'Account Type',
#        'Branch'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           300 non-null    object
#  1   Email Address  300 non-null    object
#  2   Nickname       298 non-null    object
#  3   Home Address   298 non-null    object
#  4   Password       298 non-null    object
#  5   Salt           298 non-null    object
#  6   Birthdate      298 non-null    object
#  7   Phone Number   298 non-null    object
#  8   Store ID       298 non-null    float64
#  9   Gender         298 non-null    object
#  10  Account Type   298 non-null    object
#  11  Branch         298 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 28.3+ KB

# %%
df.describe(include='all')
# Out:
#                 Name                   Email Address Nickname  \
# count            300                             300      298
# unique           203                             300      251
# top     Dario Jordan  kendrabest760@tridenttreats.bb    lat58
# freq               4                               1        3
# mean             NaN                             NaN      NaN
# std              NaN                             NaN      NaN
# min              NaN                             NaN      NaN
# 25%              NaN                             NaN      NaN
# 50%              NaN                             NaN      NaN
# 75%              NaN                             NaN      NaN
# max              NaN                             NaN      NaN
#
#                                  Home Address    Password      Salt  \
# count                                     298         298       298
# unique                                    263         278       278
# ...

# %%
df.isnull().sum()
# Out:
# Name             0
# Email Address    0
# Nickname         2
# Home Address     2
# Password         2
# Salt             2
# Birthdate        2
# Phone Number     2
# Store ID         2
# Gender           2
# Account Type     2
# Branch           2
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                   Name                         Email Address Nickname  \
# 295       Devin Holder          devinholder102@caribmail.com      NaN
# 296  Alicia Brathwaite  aliciabrathwaite780@tridenttreats.bb      NaN
#
#     Home Address Password Salt Birthdate Phone Number  Store ID Gender  \
# 295          NaN      NaN  NaN       NaN          NaN       NaN    NaN
# 296          NaN      NaN  NaN       NaN          NaN       NaN    NaN
#
#     Account Type Branch
# 295          NaN    NaN
# 296          NaN    NaN

# %%
df = df.fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# Name             0
# Email Address    0
# Nickname         0
# Home Address     0
# Password         0
# Salt             0
# Birthdate        0
# Phone Number     0
# Store ID         0
# Gender           0
# Account Type     0
# Branch           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df['Name'] = df['Name'].str.title()

# %%
df.tail()
# Out:
#                   Name                         Email Address Nickname  \
# 295       Devin Holder          devinholder102@caribmail.com  Unknown
# 296  Alicia Brathwaite  aliciabrathwaite780@tridenttreats.bb  Unknown
# 297       Tanya Holder         tanyaholder917@islandshop.net    tan96
# 298       Kendra Hinds         kendrahinds859@islandshop.net    ken73
# 299      Kendra Clarke         kendraclarke851@caribmail.com    ken73
#
#                                Home Address    Password      Salt   Birthdate  \
# 295                                 Unknown     Unknown   Unknown     Unknown
# 296                                 Unknown     Unknown   Unknown     Unknown
# 297      46 Bank Hall, St. Philip, Barbados  b]!]nY4%[]  fhjzzSLg  2002-03-03
# 298  196 Deacons Road, St. Philip, Barbados  |-.I?ZT8\:  8zFGrjXD  1961-02-09
# 299      7 St. Philip, St. Philip, Barbados  wW:]PtM<<m  WeQWHXFY  1984-04-10
#
#      Phone Number Store ID   Gender Account Type      Branch
# ...

# %%
df['Birthdate'] = pd.to_datetime(df['Birthdate'], errors='coerce')

# %%
df['Gender'] = df['Gender'].str.strip().str.title()
df['Branch'] = df['Branch'].str.strip()
df['Account Type'] = df['Account Type'].str.strip().str.title()

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           300 non-null    object
#  1   Email Address  300 non-null    object
#  2   Nickname       300 non-null    object
#  3   Home Address   300 non-null    object
#  4   Password       300 non-null    object
#  5   Salt           300 non-null    object
#  6   Birthdate      298 non-null    datetime64[ns]
#  7   Phone Number   300 non-null    object
#  8   Store ID       2 non-null      object
#  9   Gender         300 non-null    object
#  10  Account Type   300 non-null    object
#  11  Branch         300 non-null    object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 28.3+ KB

# %%
df.head()
# Out:
#               Name                   Email Address Nickname  \
# 0      José Clarke  kendrabest760@tridenttreats.bb    ken41
# 1    Zoë Callender   aliciajordan285@bdsconnect.bb    ali37
# 2       Renée Best     omarholder876@bdsconnect.bb    oma22
# 3  François Holder    devinjordan864@caribmail.com    dev39
# 4     Mårlon Forde  mårlongittens371@bdsconnect.bb    mår27
#
#                                    Home Address    Password      Salt  \
# 0  36 Grazettes Main Road, St. Philip, Barbados  n](l.2edlB  oGMbJmTP
# 1            27 Bank Hall, St. Philip, Barbados  lWmTS:Hf~6  Ih7yfJs1
# 2         72 Country Road, St. Philip, Barbados  6>UuVTA\I`  7RPeMOkI
# 3     207 Atlantic Shores, St. Philip, Barbados  OZIiB+|OB@  Fz46PDjq
# 4       127 Two Mile Hill, St. Philip, Barbados  lgot=u^2/i  yyMDHqJ3
#
#    Birthdate  Phone Number Store ID  Gender Account Type        Branch
# 0 1999-09-14  246-425-8359      NaN  Female     Standard       Oistins
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           300 non-null    object
#  1   Email Address  300 non-null    object
#  2   Nickname       300 non-null    object
#  3   Home Address   300 non-null    object
#  4   Password       300 non-null    object
#  5   Salt           300 non-null    object
#  6   Birthdate      298 non-null    datetime64[ns]
#  7   Phone Number   300 non-null    object
#  8   Store ID       2 non-null      object
#  9   Gender         300 non-null    object
#  10  Account Type   300 non-null    object
#  11  Branch         300 non-null    object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 28.3+ KB

# %%
df.tail()
# Out:
#                   Name                         Email Address Nickname  \
# 295       Devin Holder          devinholder102@caribmail.com  Unknown
# 296  Alicia Brathwaite  aliciabrathwaite780@tridenttreats.bb  Unknown
# 297       Tanya Holder         tanyaholder917@islandshop.net    tan96
# 298       Kendra Hinds         kendrahinds859@islandshop.net    ken73
# 299      Kendra Clarke         kendraclarke851@caribmail.com    ken73
#
#                                Home Address    Password      Salt  Birthdate  \
# 295                                 Unknown     Unknown   Unknown        NaT
# 296                                 Unknown     Unknown   Unknown        NaT
# 297      46 Bank Hall, St. Philip, Barbados  b]!]nY4%[]  fhjzzSLg 2002-03-03
# 298  196 Deacons Road, St. Philip, Barbados  |-.I?ZT8\:  8zFGrjXD 1961-02-09
# 299      7 St. Philip, St. Philip, Barbados  wW:]PtM<<m  WeQWHXFY 1984-04-10
#
#      Phone Number Store ID   Gender Account Type      Branch
# ...

# %%
df
# Out:
#                   Name                         Email Address Nickname  \
# 0          José Clarke        kendrabest760@tridenttreats.bb    ken41
# 1        Zoë Callender         aliciajordan285@bdsconnect.bb    ali37
# 2           Renée Best           omarholder876@bdsconnect.bb    oma22
# 3      François Holder          devinjordan864@caribmail.com    dev39
# 4         Mårlon Forde        mårlongittens371@bdsconnect.bb    mår27
# ..                 ...                                   ...      ...
# 295       Devin Holder          devinholder102@caribmail.com  Unknown
# 296  Alicia Brathwaite  aliciabrathwaite780@tridenttreats.bb  Unknown
# 297       Tanya Holder         tanyaholder917@islandshop.net    tan96
# 298       Kendra Hinds         kendrahinds859@islandshop.net    ken73
# 299      Kendra Clarke         kendraclarke851@caribmail.com    ken73
#
#                                      Home Address    Password      Salt  \
# ...

# %%
df.to_csv("TridentTreats_cleaned.csv", index=False)

# %%
clean_df = pd.read_csv("TridentTreats_cleaned.csv")

# %%
clean_df
# Out:
#                   Name                         Email Address Nickname  \
# 0          José Clarke        kendrabest760@tridenttreats.bb    ken41
# 1        Zoë Callender         aliciajordan285@bdsconnect.bb    ali37
# 2           Renée Best           omarholder876@bdsconnect.bb    oma22
# 3      François Holder          devinjordan864@caribmail.com    dev39
# 4         Mårlon Forde        mårlongittens371@bdsconnect.bb    mår27
# ..                 ...                                   ...      ...
# 295       Devin Holder          devinholder102@caribmail.com  Unknown
# 296  Alicia Brathwaite  aliciabrathwaite780@tridenttreats.bb  Unknown
# 297       Tanya Holder         tanyaholder917@islandshop.net    tan96
# 298       Kendra Hinds         kendrahinds859@islandshop.net    ken73
# 299      Kendra Clarke         kendraclarke851@caribmail.com    ken73
#
#                                      Home Address    Password      Salt  \
# ...

# %%
df.loc[263:264]
# Out:
#                Name                   Email Address Nickname  \
# 263    Devin Jordan    devinjordan864@caribmail.com    dev39
# 264  Mårlon Gittens  MÅRLONGITTENS371@BDSCONNECT.BB    mår27
#
#                                   Home Address    Password      Salt  \
# 263  207 Atlantic Shores, St. Philip, Barbados  OZIiB+|OB@  Fz46PDjq
# 264    127 Two Mile Hill, St. Philip, Barbados  lgot=u^2/i  yyMDHqJ3
#
#      Birthdate  Phone Number Store ID  Gender Account Type        Branch
# 263 1963-04-24  246-774-9830      NaN   Other        Staff        Wildey
# 264 1955-11-24  246-317-9797      NaN  Female        Staff  Speightstown

# %%
df.loc[265:266]
# Out:
#               Name                  Email Address Nickname  \
# 265  Kendra Browne  kendrabrowne446@bdsconnect.bb    ken68
# 266     Omar Hinds      OMARHINDS60@BDSCONNECT.BB    oma82
#
#                                   Home Address    Password      Salt  \
# 265  245 Atlantic Shores, St. Philip, Barbados  }}H#w#n=M>  GMmjxWkI
# 266      22 Silver Sands, St. Philip, Barbados  ~!i'qq[8)v  qH3MB9n7
#
#      Birthdate  Phone Number Store ID Gender Account Type        Branch
# 265 2004-09-01  246-813-6310      NaN   Male     Standard  Speightstown
# 266 1989-12-23  246-405-6107      NaN  Other        Staff  Speightstown

# %%
df.to_csv("TridentTreats_cleaned.csv", index=False)
